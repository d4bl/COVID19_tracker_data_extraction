# %% [markdown]
# # Data For Black Lives COVID-19 Webscraping
#
#
# <hr style="height:2pt">
#
# We manually gathered data on states reporting COVID-19 cases and deaths by race. Below, we work on automatically scraping data from websites to update data daily.

# %%
## Commented code is just FORMATTING 
import requests
# from IPython.core.display import HTML
# styles = requests.get("https://raw.githubusercontent.com/Harvard-IACS/2018-CS109A/master/content/styles/cs109.css").text
# HTML(styles)

# %%
# Import packages needed to run

import numpy as np
from bs4 import BeautifulSoup
import datetime

# %% [markdown]
# Download the webpage into a `requests` object with the following attributes:
#
# - `webpage.text`: attribute that is a string. We need this for input to BS
# - `webpage.status_code`: The `status_code` attribute returns the HTTP status code, which tells you whether your request was successful (200), or not
# - `webpage.content`: The `content` attribute gives you the raw HTML page

# %%
def url_to_soup(data_url):
    """
    Converts string into beautiful soup object for parsing
    
    Parameters
    ----------
    data_url: string
        website link
    
    Returns
    -------
    data_soup: Beautifulsoup object
        HMTL code from webpage
    """
    data_page = requests.get(data_url)
    if (data_page.status_code) == 200:
        print('request successful')
    else:
        print('request failed')

    # Create a Beautiful Soup object
    data_text = data_page.text
    data_soup = BeautifulSoup(data_text, "html.parser")

    # check to see a familiar HTML code
#     print(data_soup.prettify()[:])
    
    return data_soup

# %% [markdown]
# Create dictionary corresponds to a state and has the following data:
# - `name`: the name of the state
# - `Date Published`: date webpage updated or published
# - `Total Cases`: total number of COVID-19 cases
# - `Total Deaths`: total number of COVID-19 deaths
# - `Pct Cases Black/AA`: percentage of cases that are Black/African American
# - `Pct Deaths Black/AA`: percentage of deaths that are Black/African American

# %%
# # Georgia
GA_page = requests.get("https://dph.georgia.gov/covid-19-daily-status-report")
GA_soup = url_to_soup(GA_page)
# Out:
# ---------------------------------------------------------------------------
# LocationParseError                        Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\requests\models.py in prepare_url(self, url, params)
#     378         try:
# --> 379             scheme, auth, host, port, path, query, fragment = parse_url(url)
#     380         except LocationParseError as e:
#
# ~\anaconda3\lib\site-packages\urllib3\util\url.py in parse_url(url)
#     391     except (ValueError, AttributeError):
# --> 392         return six.raise_from(LocationParseError(source_url), None)
#     393
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# LocationParseError: Failed to parse: <Response [200]>
#
# During handling of the above exception, another exception occurred:
#
# InvalidURL                                Traceback (most recent call last)
# <ipython-input-5-9601c94577d0> in <module>
#       1 # # Georgia
#       2 GA_page = requests.get("https://dph.georgia.gov/covid-19-daily-status-report")
# ----> 3 GA_soup = url_to_soup(GA_page)
#
# <ipython-input-3-23e63d6b94dc> in url_to_soup(data_url)
#      13         HMTL code from webpage
#      14     """
# ---> 15     data_page = requests.get(data_url)
#      16     if (data_page.status_code) == 200:
#      17         print('request successful')
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     517             hooks=hooks,
#     518         )
# --> 519         prep = self.prepare_request(req)
#     520
#     521         proxies = proxies or {}
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in prepare_request(self, request)
#     460             auth=merge_setting(auth, self.auth),
#     461             cookies=merged_cookies,
# --> 462             hooks=merge_hooks(request.hooks, self.hooks),
#     463         )
#     464         return p
#
# ~\anaconda3\lib\site-packages\requests\models.py in prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     311
#     312         self.prepare_method(method)
# --> 313         self.prepare_url(url, params)
#     314         self.prepare_headers(headers)
#     315         self.prepare_cookies(cookies)
#
# ~\anaconda3\lib\site-packages\requests\models.py in prepare_url(self, url, params)
#     379             scheme, auth, host, port, path, query, fragment = parse_url(url)
#     380         except LocationParseError as e:
# --> 381             raise InvalidURL(*e.args)
#     382
#     383         if not scheme:
#
# InvalidURL: Failed to parse: <Response [200]>

# %%
# # Delaware
DE_page = requests.get("https://myhealthycommunity.dhss.delaware.gov/locations/state")
DE_soup = url_to_soup(DE_page)
# Out:
# ---------------------------------------------------------------------------
# LocationParseError                        Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\requests\models.py in prepare_url(self, url, params)
#     378         try:
# --> 379             scheme, auth, host, port, path, query, fragment = parse_url(url)
#     380         except LocationParseError as e:
#
# ~\anaconda3\lib\site-packages\urllib3\util\url.py in parse_url(url)
#     391     except (ValueError, AttributeError):
# --> 392         return six.raise_from(LocationParseError(source_url), None)
#     393
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# LocationParseError: Failed to parse: <Response [200]>
#
# During handling of the above exception, another exception occurred:
#
# InvalidURL                                Traceback (most recent call last)
# <ipython-input-6-ceeddc6be675> in <module>
#       1 # # Delaware
#       2 DE_page = requests.get("https://myhealthycommunity.dhss.delaware.gov/locations/state")
# ----> 3 DE_soup = url_to_soup(DE_page)
#
# <ipython-input-3-23e63d6b94dc> in url_to_soup(data_url)
#      13         HMTL code from webpage
#      14     """
# ---> 15     data_page = requests.get(data_url)
#      16     if (data_page.status_code) == 200:
#      17         print('request successful')
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     517             hooks=hooks,
#     518         )
# --> 519         prep = self.prepare_request(req)
#     520
#     521         proxies = proxies or {}
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in prepare_request(self, request)
#     460             auth=merge_setting(auth, self.auth),
#     461             cookies=merged_cookies,
# --> 462             hooks=merge_hooks(request.hooks, self.hooks),
#     463         )
#     464         return p
#
# ~\anaconda3\lib\site-packages\requests\models.py in prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     311
#     312         self.prepare_method(method)
# --> 313         self.prepare_url(url, params)
#     314         self.prepare_headers(headers)
#     315         self.prepare_cookies(cookies)
#
# ~\anaconda3\lib\site-packages\requests\models.py in prepare_url(self, url, params)
#     379             scheme, auth, host, port, path, query, fragment = parse_url(url)
#     380         except LocationParseError as e:
# --> 381             raise InvalidURL(*e.args)
#     382
#     383         if not scheme:
#
# InvalidURL: Failed to parse: <Response [200]>

# %%
# # Michigan
MI_page = requests.get("https://www.michigan.gov/coronavirus/0,9753,7-406-98163_98173---,00.html")
MI_soup = url_to_soup(MI_page)
# Out:
# ---------------------------------------------------------------------------
# LocationParseError                        Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\requests\models.py in prepare_url(self, url, params)
#     378         try:
# --> 379             scheme, auth, host, port, path, query, fragment = parse_url(url)
#     380         except LocationParseError as e:
#
# ~\anaconda3\lib\site-packages\urllib3\util\url.py in parse_url(url)
#     391     except (ValueError, AttributeError):
# --> 392         return six.raise_from(LocationParseError(source_url), None)
#     393
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# LocationParseError: Failed to parse: <Response [200]>
#
# During handling of the above exception, another exception occurred:
#
# InvalidURL                                Traceback (most recent call last)
# <ipython-input-7-0a29444b150c> in <module>
#       1 # # Michigan
#       2 MI_page = requests.get("https://www.michigan.gov/coronavirus/0,9753,7-406-98163_98173---,00.html")
# ----> 3 MI_soup = url_to_soup(MI_page)
#
# <ipython-input-3-23e63d6b94dc> in url_to_soup(data_url)
#      13         HMTL code from webpage
#      14     """
# ---> 15     data_page = requests.get(data_url)
#      16     if (data_page.status_code) == 200:
#      17         print('request successful')
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     517             hooks=hooks,
#     518         )
# --> 519         prep = self.prepare_request(req)
#     520
#     521         proxies = proxies or {}
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in prepare_request(self, request)
#     460             auth=merge_setting(auth, self.auth),
#     461             cookies=merged_cookies,
# --> 462             hooks=merge_hooks(request.hooks, self.hooks),
#     463         )
#     464         return p
#
# ~\anaconda3\lib\site-packages\requests\models.py in prepare(self, method, url, headers, files, data, params, auth, cookies, hooks, json)
#     311
#     312         self.prepare_method(method)
# --> 313         self.prepare_url(url, params)
#     314         self.prepare_headers(headers)
#     315         self.prepare_cookies(cookies)
#
# ~\anaconda3\lib\site-packages\requests\models.py in prepare_url(self, url, params)
#     379             scheme, auth, host, port, path, query, fragment = parse_url(url)
#     380         except LocationParseError as e:
# --> 381             raise InvalidURL(*e.args)
#     382
#     383         if not scheme:
#
# InvalidURL: Failed to parse: <Response [200]>

# %%
# Minnesota Webscraping
MN_url = "https://www.health.state.mn.us/diseases/coronavirus/situation.html#raceeth1"
MN_soup = url_to_soup(MN_url)

# find date and total number of cases and deaths
counter = 0
num_cases = ''
num_deaths = ''
for strong_tag in MN_soup.find_all('strong'):
    this_string = strong_tag.text, strong_tag.next_sibling
    this_heading = strong_tag.text
    if counter == 0:
        date_text = strong_tag.text.strip('.')[11:]
    if this_heading == 'Total positive: ':
        num_cases = strong_tag.next_sibling
    if this_heading == 'Deaths: ':
        num_deaths = strong_tag.next_sibling
    counter += 1
    
date_time_obj = datetime.datetime.strptime(date_text, "%B %d, %Y")
date_formatted = date_time_obj.strftime("%m/%d/%Y")
print('Date:', date_formatted)
print('Number Cases:', num_cases)
print('Number Deaths:', num_deaths)

# find number of Black/AA cases and deaths
table = MN_soup.find("div", attrs={"id":"raceeth"})
counter = 0
pct_cases = ''
pct_deaths = ''
for th in table.find_all('th'):
    text = th.text
#     print(th.next_sibling)
    if text == "Black":
#         print(table.find_all('td'))
        pct_cases = table.find_all('td')[counter-2].text.strip('%')
        pct_deaths = table.find_all('td')[counter-1].text.strip('%')
    counter += 1

print('Pct Cases Black/AA:', pct_cases)
print('Pct Deaths Black/AA:', pct_deaths)
# Out:
# request successful
# Date: 05/03/2020
# Number Cases: 6,663
# Number Deaths: 419
#
# Pct Cases Black/AA: 15
# Pct Deaths Black/AA: 4

# %%
# North Carollina
NC_url = "https://www.ncdhhs.gov/divisions/public-health/covid19/covid-19-nc-case-count#by-race-ethnicity"
NC_soup = url_to_soup(NC_url)

# find date and total number of cases and deaths
date_text = NC_soup.find("div", attrs={"class":"field-item"}).p.text[50:]
date_time_obj = datetime.datetime.strptime(date_text, "%B %d, %Y. ")
date_formatted = date_time_obj.strftime("%m/%d/%Y")


field_item = NC_soup.find("div", attrs={"class":"field-item"})
# num_cases = field_item.findAll("tr")[1].td.text
items = field_item.findAll("tr")[1]
num_cases = items.findAll("td")[1].text
num_deaths = items.findAll("td")[0].text

print('Date:', date_formatted)
print('Number Cases:', num_cases)
print('Number Deaths:', num_deaths)

# find number of Black/AA cases and deaths
tables = NC_soup.findAll("table")
race_data = tables[4]
num_race_cases = race_data.findAll("td")[6]
num_race_deaths = race_data.findAll("td")[8]
pct_cases = race_data.findAll("td")[22].text.strip('%')
pct_deaths = race_data.findAll("td")[24].text.strip('%')

print('Pct Cases Black/AA:', pct_cases)
print('Pct Deaths Black/AA:', pct_deaths)
# Out:
# request successful
# Date: 05/04/2020
# Number Cases: 430
# Number Deaths: 11,848
# Pct Cases Black/AA: 37
# Pct Deaths Black/AA: 34

# %%
# Texas
TX_url = "https://cosagis.maps.arcgis.com/apps/opsdashboard/index.html#/d2c7584fe9fd4da1b30cb9d6cc311163"
TX_soup = url_to_soup(TX_url)
# Out:
# request successful

# %%
# TX_soup.find("div", attrs={"id":"ember522"})
# TX_soup.body.find("div", attrs={"id":"ember53"})
# TX_soup.findAll("body")
# Out:
# [<body class="claro">
#  <script data-amd="true" src="https://js.arcgis.com/3.32/init.js"></script>
#  <script data-amd-loading="true" src="assets/amd-loading-d8029d0343fa400ebae9865c42984750.js"></script>
#  <div class="full-height flex-vertical flex-justify-center flex-align-items-center" id="initialLoadingContainer">
#  <div class="loader is-active">
#  <div class="loader-bars"></div>
#  </div>
#  </div>
#  </body>]

# %%
#ember522 > svg > g.responsive-text-label > svg > text
TX_soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>ArcGIS Dashboards</title>
# <meta content="" name="description"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="assets/images/favicon.ico?" rel="icon" type="image/x-icon"/>
# <link href="https://js.arcgis.com/3.32/dijit/themes/claro/claro.css" rel="stylesheet" type="text/css"/>
# <link href="https://js.arcgis.com/3.32/esri/css/esri.css" rel="stylesheet" type="text/css"/>
# <link href="assets/vendor-ff6a5e0c0264e398e1ffaeb015926635.css" rel="stylesheet"/>
# <link href="assets/app-light-7137f008b303d663c3645f07f162e89f.css" rel="stylesheet"/>
# <script src="assets/amd-config-7e9801fc9c916a27bb75c6f356e09e0d.js"></script>
# </head>
# <body class="claro">
# <script data-amd="true" src="https://js.arcgis.com/3.32/init.js"></script>
# <script data-amd-loading="true" src="assets/amd-loading-d8029d0343fa400ebae9865c42984750.js"></script>
# <div class="full-height flex-vertical flex-justify-center flex-align-items-center" id="initialLoadingContainer">
# <div class="loader is-active">
# <div class="loader-bars"></div>
# </div>
# </div>
# </body>
# </html>

# %%
# raw_data = TX_soup.find("body", attrs={"class":"claro"})
# raw_data.findAll('script')[1]

# %%
# Wisconsin (Milwaukee)
WI_url = "https://county.milwaukee.gov/EN/COVID-19"
WI_soup = url_to_soup(WI_url)
# Out:
# request successful

# %%
# WI_soup.findAll("div", attrs={"class":"embed-container"})
print(WI_soup.prettify()[:])
# Out:
# <!DOCTYPE doctype html>
# <html class="Unknown 0_0 Unknown Unknown titanDisplay" id="htmlTag" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta content="initial-scale=1,maximum-scale=4.0,minimum-scale=1.0,user-scalable=0,width=device-width" name="viewport"/>
#   <link href="//fonts.googleapis.com/css?family=Lato:400,400italic,700|Oswald:400,300,700" rel="stylesheet" type="text/css"/>
#   <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js">
#   </script>
#   <script src="/CommonScripts/NWS.js">
#   </script>
#   <script language="JavaScript" src="/CommonScripts/jquery.bxslider.js" type="text/javascript">
#   </script>
#   <script src="//code.jquery.com/ui/1.12.1/jquery-ui.js">
#   </script>
#   <link href="/CommonScripts/fancybox/jquery.fancybox.css?v=2.1.5" media="screen" rel="stylesheet" type="text/css">
#    <script src="/CommonScripts/fancybox/jquery.fancybox.pack.js?v=2.1.5" type="text/javascript">
#    </script>
#    <script language="JavaScript" src="/CommonScripts/MilwaukeeCounty.js" type="text/javascript">
#    </script>
#    <style>
#     #featureImage{background-image: url("/County-Files/County-of-Milwaukee/MilwaukeeCountyFeaturedHome.jpg");}
#    </style>
#    <!-- Google Tag Manager -->
#    <script>
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-K6CNP5X');
#    </script>
#    <!-- End Google Tag Manager -->
#    <link href="/ClientCss/milwaukeecounty.css" rel="stylesheet" type="text/css"/>
#    <link href="/ClientCss/milwaukeecounty_styles.css" rel="stylesheet" type="text/css"/>
#    <link href="/ClientCss/milwaukeecounty_center.css" rel="stylesheet" type="text/css"/>
#    <meta content="Titan CMS" name="creator"/>
#    <title id="pageTitle">
#     COVID-19
#    </title>
#    <meta content="326970" name="DocID"/>
#    <meta content="COVID-19" name="Title"/>
#    <meta content="coronavirus Milwaukee, covid 19 cases in wi, covid 19 Milwaukee, COVID-19, Milwaukee coronavirus, Milwaukee coronavirus cases, Milwaukee county coronavirus, Milwaukee county coronavirus dashboard, Milwaukee covid, Milwaukee covid 19" name="Keywords"/>
#    <meta content="" name="Description"/>
#    <meta content="" name="Abstract"/>
#    <link href="/display/WhatsNew.rss" rel="alternate+rss" title="RSS" type="application/rss+xml"/>
#    <script src="/Scripts/titanscripts.js" type="text/javascript">
#    </script>
#    <script src="/Scripts/Banner.js" type="text/javascript">
#    </script>
#    <script src="/CommonScripts/pausescroller.js" type="text/javascript">
#    </script>
#    <!-- Google Tag Manager (noscript) -->
#    <noscript>
#     <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-K6CNP5X" style="display:none;visibility:hidden" width="0">
#     </iframe>
#    </noscript>
#    <!-- End Google Tag Manager (noscript) -->
#    <link href="/County-Files/County-of-Milwaukee/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#    <link href="/County-Files/County-of-Milwaukee/favicon.ico" rel="icon" type="image/x-icon"/>
#   </link>
#  </head>
#  <body class="titanBody" id="bodyTag" onclick="if (window['TitanClickHandler']) TitanClickHandler(this, event)" onload="TitanLoad();">
#   <form action="/EN/COVID-19?" enctype="multipart/form-data" id="routerForm" method="post" name="routerForm">
#    <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="..."/>
#    <script src="/CommonScripts/NWSAjaxSupport.js" type="text/javascript">
#    </script>
#    <script src="/display/components/Blocks/CustomBlocks/SearchBar/Support/SearchBarSupport.js" type="text/javascript">
#    </script>
#    <script src="/ScriptResource.axd?d=1vi7h71mbKPqgetf-tMpauTPHfCX0yjxD9YaL__ocTwSKStY1nYknV0iH3dYbO8diiK1N12fQvmeslzDW-G2O9McNGv_PjW_lKP3I8HLqhzaYvtJmLaGgZnlL1vBbtAqorsE4H3ri5zeJfudHOfKimkykam6yQP712kbHyq3ZXA1&amp;t=ffffffff9a9577e8" type="text/javascript">
#    </script>
#    <script src="/display/components/Blocks/CustomBlocks/SearchBar/Support/SearchBarAjax.asmx/js" type="text/javascript">
#    </script>
#    <script src="/display/components/Blocks/AggregationV2/Support/AggregationV2Ajax.asmx/js" type="text/javascript">
#    </script>
#    <script src="/display/components/Blocks/Commenting/Support/CommentingAjax.asmx/js" type="text/javascript">
#    </script>
#    <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="F2287FB4"/>
#    <div id="printHeader">
#     <div class="siteBounds">
#     </div>
#    </div>
#    <div id="headerWrapper">
#     <div id="headerWrapperInside">
#      <div class="siteBounds">
#       <div id="logoWrapper">
#        <div id="logoControlContainer">
#         <div id="logoContainer">
#          <a href="/EN">
#           <img alt="County of Milwaukee" border="0" src="/County-Files/County-of-Milwaukee/MilwaukeeCountyLogo.png"/>
#          </a>
#         </div>
#        </div>
#        <div id="milwaukeeText">
#         <span class="MilaukeeCounty">
#          Milwaukee County
#         </span>
#         <span class="Wisconsin">
#          Wisconsin
#         </span>
#        </div>
#       </div>
#      </div>
#      <div id="mobileMenuButton">
#       <a title="Open Menu">
#        <i aria-hidden="true" class="fa fa-bars">
#        </i>
#       </a>
#      </div>
#      <div id="mobileSearchButton">
#       <a title="Search">
#        <i aria-hidden="true" class="fa fa-search">
#        </i>
#       </a>
#      </div>
#      <div id="topNavWrapper">
#       <div id="topControls">
#        <div class="siteBounds">
#         <div blockinfo="Freeform New100 CenterZone TitanBlock" class="Freeform New100 CenterZone TitanBlock">
#          <ul>
#           <li>
#            <a href="/EN/how-do-i" linktype="2" target="_self">
#             How Do I...
#            </a>
#           </li>
#           <li>
#            <a href="/EN/our-county" linktype="2" target="_self">
#             Our County
#            </a>
#           </li>
#           <li>
#            <a href="/EN/residents" linktype="2" target="_self">
#             Residents
#            </a>
#           </li>
#           <li>
#            <a href="/EN/businesses" linktype="2" target="_self">
#             Businesses
#            </a>
#           </li>
#           <li>
#            <a href="/EN/news--events" linktype="2" target="_self">
#             News &amp; Events
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div id="desktopSearchButton">
#          <a tabindex="0" title="Search">
#           <i aria-hidden="true" class="fa fa-search">
#           </i>
#          </a>
#         </div>
#         <div id="MegaMenuItems" style="display:none;">
#          <div class="MenuContainer" id="MegaMenu1">
#           <div class="MenuContainerInside">
#            <div blockinfo="Freeform New100 CenterZone TitanBlock" class="Freeform New100 CenterZone TitanBlock">
#             <ul>
#              <li>
#               <a href="/EN/How-Do-I/Find" linktype="3" target="_self">
#                Find
#               </a>
#               <ul>
#                <li>
#                 <a href="/EN/Parks/Explore/Find-a-Park" linktype="3" target="_self">
#                  Parks
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Human-Resources" linktype="3" target="_self">
#                  Jobs
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Courts/Jury-Duty#court_locations" linktype="3" target="_self">
#                  Court Locations
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/County-Clerk/Election-Commission">
#                  Voting Information
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/administrative-services/Bids-and-RFPs">
#                  Bid &amp; Contract Opportunities
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li>
#               <a href="/EN/How-Do-I/Pay">
#                Pay
#               </a>
#               <ul>
#                <li>
#                 <a href="/EN/Sheriff/How-Do-I/Pay-a-Ticket" linktype="3" target="_self">
#                  Judgments &amp; Citations
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Treasurer/Delinquent-Property-Taxes" linktype="3" target="_self">
#                  Delinquent Property Taxes
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Sheriff/How-Do-I/Pay-a-Ticket" linktype="3" target="_self">
#                  Parking Tickets
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Child-Support-Services/Payments--Fees">
#                  Child Support
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li>
#               <a href="/EN/How-Do-I/Attend">
#                Attend
#               </a>
#               <ul>
#                <li>
#                 <a href="/EN/Courts/Jury-Duty">
#                  Jury Duty
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Courts">
#                  Court
#                 </a>
#                </li>
#                <li>
#                 <a href="https://milwaukeecounty.legistar.com/Calendar.aspx" target="_blank">
#                  Meetings
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/News--Events/Events">
#                  Events
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li>
#               <a href="/EN/How-Do-I/Apply">
#                Apply
#               </a>
#               <ul>
#                <li>
#                 <a href="/EN/Human-Resources">
#                  Careers
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Parks/Plan/Get-a-Permit">
#                  Permits
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Register-of-Deeds/Vital-Records">
#                  Birth Certificates
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/County-Clerk/Marriage-License">
#                  Marriage License
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li>
#               <a href="/EN/How-Do-I/Report">
#                Report
#               </a>
#               <ul>
#                <li>
#                 <a href="/EN/District-Attorney/Crime" linktype="3" target="_self">
#                  Crime
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Comptroller/Fraud-Waste-Abuse" linktype="3" target="_self">
#                  Fraud
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/County-Clerk/File-a-Claim">
#                  Claims &amp; Complaints
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Ethics-Board">
#                  Ethics Violations
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Office-for-Persons-with-Disabilities/ADA">
#                  Accessibility Issues
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Department-of-Transportation#Report_an_Issue">
#                  Road Issues
#                 </a>
#                </li>
#               </ul>
#              </li>
#             </ul>
#            </div>
#            <div blockinfo="Freeform New100 CenterZone TitanBlock" class="Freeform New100 CenterZone TitanBlock">
#             <h4>
#              <img alt="" src="/County-Files/County-of-Milwaukee/MilwaukeeCountyFeaturedHome.jpg?Medium"/>
#             </h4>
#             <h4>
#              Welcome to Milwaukee County
#             </h4>
#             <p>
#              Milwaukee County’s goal is to enrich your life by providing essential services that meet your needs and those of your family, neighbors, co-workers and friends.
#             </p>
#            </div>
#           </div>
#          </div>
#          <div class="MenuContainer" id="MegaMenu2">
#           <div class="MenuContainerInside">
#            <div blockinfo="Freeform New100 CenterZone TitanBlock" class="Freeform New100 CenterZone TitanBlock">
#             <ul>
#              <li>
#               <a href="/EN/Vision" linktype="3" target="_self">
#                Vision
#               </a>
#               <ul>
#                <li>
#                 <a href="/EN/Vision/Racial-Equity-Framework" linktype="3" target="_self">
#                  Racial Equity Framework
#                 </a>
#                </li>
#                <li>
#                 <a href="https://county.milwaukee.gov/EN/Vision#threeyearobjectives" linktype="3" target="_self">
#                  Three-Year Objectives
#                 </a>
#                </li>
#                <li>
#                 <a href="https://county.milwaukee.gov/EN/Vision#progress" linktype="3" target="_self">
#                  Progress
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li>
#               <a href="/EN/County-Executive" linktype="3" target="_self">
#                County Executive
#               </a>
#               <ul>
#                <li>
#                 <a href="/EN/County-Executive/contact" linktype="3" target="_self">
#                  Contact the County Executive
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/County-Executive#updates" linktype="3" target="_self">
#                  Sign up for Updates
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/administrative-services/performance-strategy-and-budget" linktype="3" target="_self">
#                  County Budget Information
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/County-Executive/contact/proclamation-requests" linktype="3" target="_self">
#                  Request a Proclamation
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/County-Executive/news" linktype="3" target="_self">
#                  News
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/County-Executive/contact/internships" linktype="3" target="_self">
#                  Internships
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li>
#               <a href="/EN/Board-of-Supervisors" linktype="3" target="_self">
#                Board of Supervisors
#               </a>
#               <ul>
#                <li>
#                 <a href="	http://www.findyourcountysupervisor.com/" linktype="3" target="_blank">
#                  Find Your Supervisor
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Board-of-Supervisors/Board-Members" linktype="3" target="_self">
#                  County Board Members
#                 </a>
#                </li>
#                <li>
#                 <a href="https://milwaukeecounty.legistar.com/Calendar.aspx" linktype="3" target="_blank">
#                  Meeting Schedules and Agendas
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Board-of-Supervisors/Standing-Committees" linktype="3" target="_self">
#                  Standing Committees
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Board-of-Supervisors/Fair-Deal" linktype="3" target="_self">
#                  Fair Deal
#                 </a>
#                </li>
#                <li>
#                 <a href="https://milwaukeecounty.legistar.com/Legislation.aspx" linktype="3" target="_blank">
#                  County Legislative Information Center (CLIC)
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li>
#               <a href="/EN/our-county/Other-Elected-Officials" linktype="3" target="_self">
#                Other Elected Officials
#               </a>
#               <ul>
#                <li>
#                 <a href="/EN/Comptroller" linktype="3" target="_self">
#                  Comptroller
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Courts/Clerk-of-Courts" linktype="3" target="_self">
#                  Clerk of Courts
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/County-Clerk" linktype="3" target="_self">
#                  County Clerk
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN//District-Attorney" linktype="3" target="_self">
#                  District Attorney
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Treasurer" linktype="3" target="_self">
#                  Treasurer
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Register-of-Deeds" linktype="3" target="_self">
#                  Register of Deeds
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Sheriff" linktype="3" target="_self">
#                  Sheriff
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li>
#               <a href="/EN/Our-County/Departments--Divisions" linktype="2" target="_self">
#                Departments &amp; Divisions
#               </a>
#               <ul>
#                <li>
#                 <a href="/EN/Parks" linktype="3" target="_self">
#                  Parks
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Courts" linktype="3" target="_self">
#                  Courts
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Sheriff" linktype="3" target="_self">
#                  Sheriff's Office
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/DHHS" linktype="3" target="_self">
#                  Department of Health &amp; Human Services
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Human-Resources" linktype="3" target="_self">
#                  Human Resources
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/House-of-Correction" linktype="3" target="_self">
#                  House of Correction
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Child-Support-Services" linktype="3" target="_self">
#                  Child Support Services
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Our-County/Departments--Divisions/Other-Departments" linktype="2" target="_self">
#                  All Departments
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li>
#               <a href="/EN/our-county/Budget--Finance" linktype="3" target="_self">
#                Budget &amp; Finance
#               </a>
#               <ul>
#                <li>
#                 <a href="/EN/Administrative-Services/Performance-Strategy-and-Budget#2019" linktype="3" target="_self">
#                  Current Budget
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Administrative-Services/Performance-Strategy-and-Budget" linktype="3" target="_self">
#                  How the Budget Works
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Administrative-Services/Performance-Strategy-and-Budget/Budget-Archive" linktype="3" target="_self">
#                  Previous Year Budgets
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Comptroller/Reports" linktype="3" target="_self">
#                  Annual Financial Reports
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li>
#               <a href="/EN/our-county/Public-Records" linktype="3" target="_self">
#                Public Records
#               </a>
#               <ul>
#                <li>
#                 <a href="/EN/Register-of-Deeds/Vital_Records" linktype="3" target="_self">
#                  Get a Birth Certificate
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Register-of-Deeds/Real-Estate-Record-Access" linktype="3" target="_self">
#                  Real Estate Records
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Administrative-Services/Land-Information-Office" linktype="2" target="_self">
#                  GIS Applications
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Administrative-Services/AMOP" linktype="3" target="_self">
#                  County Operating Procedures
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN//Ethics-Board" linktype="3" target="_self">
#                  Ethics Board
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/our-county/Public-Records/Open-Records-Request" linktype="3" target="_self">
#                  Open Records Request
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li>
#               <a href="/EN/our-county/elections--voting" linktype="3" target="_self">
#                Elections &amp; Voting
#               </a>
#               <ul>
#                <li>
#                 <a href="/EN/County-Clerk/Election-Commission" linktype="3" target="_self">
#                  Voter Information
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/County-Clerk/Election-Commission#CurrentElectedOfficials" linktype="3" target="_self">
#                  Current Elected Officials
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/County-Clerk/Election-Commission/Election-Results" linktype="3" target="_self">
#                  Historic Election Results
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/County-Clerk/Election-Commission/Campaign-Finance-Reports" linktype="3" target="_self">
#                  Campaign Finance Reports
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/County-Clerk/Election-Commission/How-to-Run-for-Office" linktype="3" target="_self">
#                  Running for County Office
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/County-Clerk/Election-Commission#BringToBallot" linktype="3" target="_self">
#                  Bring It to the Ballot
#                 </a>
#                </li>
#               </ul>
#              </li>
#             </ul>
#            </div>
#            <div blockinfo="Freeform New100 CenterZone TitanBlock" class="Freeform New100 CenterZone TitanBlock">
#             <h4>
#              <img alt="" src="/County-Files/County-of-Milwaukee/OurCountyMegaMenu.jpg"/>
#             </h4>
#             <h4>
#              Our County
#             </h4>
#             <p>
#              We enhance the quality of life in Milwaukee County through great public service.
#             </p>
#            </div>
#           </div>
#          </div>
#          <div class="MenuContainer" id="MegaMenu3">
#           <div class="MenuContainerInside">
#            <div blockinfo="Freeform New100 CenterZone TitanBlock" class="Freeform New100 CenterZone TitanBlock">
#             <ul>
#              <li>
#               <a href="/EN/Parks" linktype="3" target="_self">
#                Parks &amp; Recreation
#               </a>
#               <ul>
#                <li>
#                 <a href="/EN/Parks/Explore/Find-a-Park" linktype="3" target="_self">
#                  Find a Park
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Parks/Explore/Water-Parks--Pools" linktype="3" target="_self">
#                  Swimming Pools
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Parks/Explore/Trails" linktype="3" target="_self">
#                  Trails
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Parks/Explore/Beer-Gardens" linktype="3" target="_self">
#                  Beer Gardens
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Parks/Plan/rent-a-venue" linktype="3" target="_self">
#                  Rentals &amp; Permits
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li>
#               <a href="/EN/Residents/Arts--Culture" linktype="3" target="_self">
#                Arts &amp; Culture
#               </a>
#               <ul>
#                <li>
#                 <a href="http://www.marcuscenter.org/" linktype="3" target="_blank">
#                  Marcus Center for the Performing Arts
#                 </a>
#                </li>
#                <li>
#                 <a href="http://www.milwaukeezoo.org/" linktype="3" target="_blank">
#                  Milwaukee County Zoo
#                 </a>
#                </li>
#                <li>
#                 <a href="https://mam.org/" linktype="3" target="_blank">
#                  Milwaukee Art Museum
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.mpm.edu/" linktype="3" target="_blank">
#                  Milwaukee Public Museum
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.charlesallis.org/" linktype="3" target="_blank">
#                  Charles Allis Art Museum
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.villaterrace.org/" linktype="3" target="_blank">
#                  Villa Terrace Decorative Arts Museum
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Parks/Explore/Boerner-Botanical-Gardens" linktype="3" target="_self">
#                  Boerner Botanical Gardens
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Parks/Explore/The-Domes" linktype="3" target="_self">
#                  Mitchell Park Domes
#                 </a>
#                </li>
#                <li>
#                 <a href="https://milwaukeehistory.net/" linktype="3" target="_blank">
#                  Milwaukee County Historical Society
#                 </a>
#                </li>
#                <li>
#                 <a href="https://warmemorialcenter.org/" linktype="3" target="_blank">
#                  War Memorial Center
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li>
#               <a href="/EN/residents/transportation" linktype="3" target="_self">
#                Transportation
#               </a>
#               <ul>
#                <li>
#                 <a href="/EN/County-Clerk/Other-Services/Purchase-Mcard" linktype="3" target="_self">
#                  Purchase MCTS Bus Fare
#                 </a>
#                </li>
#                <li>
#                 <a href="http://www.ridemcts.com" linktype="3" target="_blank">
#                  Milwaukee County Transit System
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.mitchellairport.com" linktype="3" target="_blank">
#                  MKE – Mitchell Airport
#                 </a>
#                </li>
#                <li>
#                 <a href="http://timmermanairport.com/" linktype="3" target="_blank">
#                  Timmerman Airport
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/department-of-Transportation" linktype="3" target="_self">
#                  Department of Transporation
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li>
#               <a href="/EN/Residents/Public-Safety--Justice" linktype="3" target="_self">
#                Public Safety &amp; Justice
#               </a>
#               <ul>
#                <li>
#                 <a href="/EN/courts/court-services" linktype="3" target="_self">
#                  Court Services
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/House-of-Correction" linktype="3" target="_self">
#                  House of Corrections
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Sheriff" linktype="3" target="_self">
#                  Sheriff's Office
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Medical-Examiner" linktype="3" target="_self">
#                  Medical Examiner
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Office-of-Emergency-Management" linktype="3" target="_self">
#                  Office of Emergency Management
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/District-Attorney" linktype="3" target="_self">
#                  District Attorney
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Child-Support-Services" linktype="3" target="_self">
#                  Child Support Services
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Office-for-Persons-with-Disabilities" linktype="3" target="_self">
#                  Office for Persons with Disabilities
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/mcjc" linktype="3" target="_self">
#                  Milwaukee Community Justice Council
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li>
#               <a href="/EN/Residents/children--Families" linktype="3" target="_self">
#                Children &amp; Families
#               </a>
#               <ul>
#                <li>
#                 <a href="/EN/Child-Support-Services" linktype="3" target="_self">
#                  Child Support Services
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/County-Clerk/Marriage-License" linktype="3" target="_self">
#                  Getting Married
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/dhhs/dyfs" linktype="3" target="_self">
#                  Youth &amp; Family Services
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Courts/Court-Divisions/Childrens-Court" linktype="3" target="_self">
#                  Children's Court
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Veterans-Services" linktype="3" target="_self">
#                  Veterans' Services
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li>
#               <a href="/EN/residents/Health--Human-Services" linktype="3" target="_self">
#                Health &amp; Human Services
#               </a>
#               <ul>
#                <li>
#                 <a href="/EN/DHHS/BHD" linktype="3" target="_self">
#                  Behavioral Health Help
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Department-on-Aging" linktype="3" target="_self">
#                  Aging &amp; Older Adults
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/DHHS/dsd" linktype="3" target="_self">
#                  Disability Services
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/dhhs/bhd" linktype="3" target="_self">
#                  Comprehensive Community Services
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/dhhs/bhd" linktype="3" target="_self">
#                  Crisis Clinics &amp; Centers
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Office-for-Persons-with-Disabilities" linktype="3" target="_self">
#                  Office for Persons with Disabilities
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li>
#               <a href="/EN/residents/Housing--Development" linktype="3" target="_self">
#                Housing &amp; Development
#               </a>
#               <ul>
#                <li>
#                 <a href="/EN/DHHS/Housing#homeRepair" linktype="3" target="_self">
#                  Home Repair
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/DHHS/Energy-Assistance" linktype="3" target="_self">
#                  Energy Assistance
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/dhhs/housing/housing-first" linktype="3" target="_self">
#                  Economic Support
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/administrative-services/land-information-office" linktype="3" target="_self">
#                  Maps &amp; Data
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Register-of-Deeds/Real-Estate-Record-Access" linktype="3" target="_self">
#                  Real Estate Records
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Administrative-Services/Economic-Development/Foreclosed-Properties" linktype="3" target="_self">
#                  Foreclosed Properties for Sale
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/dhhs/housing" linktype="3" target="_self">
#                  Housing Division
#                 </a>
#                </li>
#               </ul>
#              </li>
#             </ul>
#            </div>
#            <div blockinfo="Freeform New100 CenterZone TitanBlock" class="Freeform New100 CenterZone TitanBlock">
#             <h4>
#              <img alt="" src="/County-Files/County-of-Milwaukee/ResidentMegaMenu.jpg"/>
#             </h4>
#             <h4>
#              Residents
#             </h4>
#             <p>
#              Milwaukee County is home to over 950,000 people living in one of 19 communities, which range in size from the City of Milwaukee, with 595,000 residents, to the Village of River Hills, with roughly 1,600 residents.
#             </p>
#            </div>
#           </div>
#          </div>
#          <div class="MenuContainer" id="MegaMenu4">
#           <div class="MenuContainerInside">
#            <div blockinfo="Freeform New100 CenterZone TitanBlock" class="Freeform New100 CenterZone TitanBlock">
#             <ul>
#              <li>
#               <a href="/EN/businesses/Doing-Business-with-the-County" linktype="3" target="_self">
#                Doing Business With the County
#               </a>
#               <ul>
#                <li>
#                 <a href="/EN/Businesses/Doing-Business-with-the-County/First-Steps-in-Doing-Business-with-Milwaukee-County" linktype="3" target="_self">
#                  First Steps in Doing Business With Milwaukee County
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/administrative-services/bids-and-rfps" linktype="3" target="_self">
#                  Bids &amp; RFPs
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/administrative-services/community-business-development-partners/resources#ucp" linktype="3" target="_self">
#                  Vendor Information
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/administrative-services/procurement#DocuSign" linktype="3" target="_self">
#                  DocuSign Training
#                 </a>
#                </li>
#                <li>
#                 <a href="/En/administrative-services/land-information-office/gis-applications" linktype="3" target="_self">
#                  Maps &amp; Apps
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li>
#               <a href="/EN/administrative-services/Community-Business-Development-Partners" linktype="3" target="_self">
#                Community Business Development Partners
#               </a>
#               <ul>
#                <li>
#                 <a href="/EN/administrative-services/Community-Business-Development-Partners#certification" linktype="3" target="_self">
#                  Certification Services
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/administrative-services/Community-Business-Development-Partners/resources#ucp" linktype="3" target="_self">
#                  Certified Vendor List
#                 </a>
#                </li>
#                <li>
#                 <a href="https://mke.diversitycompliance.com/Default.asp" linktype="3" target="_blank">
#                  B2GNow Access
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/administrative-services/Community-Business-Development-Partners#Revolving_Loan_Program" linktype="3" target="_self">
#                  Revolving Loan Program
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/administrative-services/Community-Business-Development-Partners/Resources#goal_reports" linktype="3" target="_self">
#                  DBE Goal Reports
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li>
#               <a href="/EN/Administrative-Services/Land-Information-Office" linktype="3" target="_self">
#                Land Information
#               </a>
#               <ul>
#                <li>
#                 <a href="/EN/Administrative-Services/Land-Information-Office/GIS-Applications" linktype="3" target="_self">
#                  GIS Applications
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Administrative-Services/Land-Information-Office/GIS-Data-Downloads" linktype="3" target="_self">
#                  GIS Data Downloads
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Administrative-Services/Land-Information-Office/Maps" linktype="3" target="_self">
#                  Maps
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Administrative-Services/Land-Information-Office/Projects" linktype="3" target="_self">
#                  Projects
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Administrative-Services/Land-Information-Office/about-us/Land-Information-Council" linktype="3" target="_self">
#                  Land Information Council
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Administrative-Services/Land-Information-Office/About-Us" linktype="3" target="_self">
#                  About
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li>
#               <a href="/EN/businesses/taxes--payments" linktype="3" target="_self">
#                Taxes &amp; Payments
#               </a>
#               <ul>
#                <li>
#                 <a href="/EN/Treasurer/Delinquent-Property-Taxes" linktype="3" target="_self">
#                  Pay Delinquent Property Taxes
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Treasurer#unclaimed_funds" linktype="3" target="_self">
#                  Unclaimed Funds
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Treasurer#tax_credit" linktype="3" target="_self">
#                  Tax Credits
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li>
#               <a href="/EN/administrative-services/Economic-Development" linktype="3" target="_self">
#                Economic Development
#               </a>
#               <ul>
#                <li>
#                 <a href="/EN/administrative-services/Economic-Development#Projects" linktype="3" target="_self">
#                  Projects
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/administrative-services/bids-and-RFPs" linktype="3" target="_self">
#                  Bids &amp; RFPs
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Administrative-Services/Economic-Development/Foreclosed-Properties" linktype="3" target="_self">
#                  Real Estate
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/administrative-services/economic-development#contact_us" linktype="3" target="_self">
#                  Contact
#                 </a>
#                </li>
#               </ul>
#              </li>
#             </ul>
#            </div>
#            <div blockinfo="Freeform New100 CenterZone TitanBlock" class="Freeform New100 CenterZone TitanBlock">
#             <h4>
#              <img alt="" src="/County-Files/County-of-Milwaukee/BusinessMegaMenu.jpg"/>
#             </h4>
#             <h4>
#              Businesses
#             </h4>
#             <p>
#              Still a manufacturing stronghold, the region features 16 Fortune 1000 companies and thousands of others in the financial services, medical device, hospitality and retailing industries.
#             </p>
#            </div>
#           </div>
#          </div>
#          <div class="MenuContainer" id="MegaMenu5">
#           <div class="MenuContainerInside">
#            <div blockinfo="Freeform New100 CenterZone TitanBlock" class="Freeform New100 CenterZone TitanBlock">
#             <ul>
#              <li>
#               <a href="/EN/News--Events/Events" linktype="3" target="_self">
#                Events
#               </a>
#               <ul>
#                <li>
#                 <a href="/EN/Parks/Experience/Events-Calendar" linktype="3" target="_self">
#                  Events at the Parks
#                 </a>
#                </li>
#                <li>
#                 <a href="https://milwaukeecounty.legistar.com/Calendar.aspx" linktype="3" target="_blank">
#                  Board Meetings
#                 </a>
#                </li>
#                <li>
#                 <a href="https://milwaukeecounty.legistar.com/Calendar.aspx" linktype="3" target="_blank">
#                  Committee Meetings
#                 </a>
#                </li>
#                <li>
#                 <a href="https://milwaukeecounty.legistar.com/Calendar.aspx" linktype="3" target="_blank">
#                  Subcommittee Meetings
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li>
#               <a href="/EN/News--Events/News" linktype="3" target="_self">
#                News
#               </a>
#               <ul>
#                <li>
#                 <a href="/EN/Board-of-Supervisors/News" linktype="3" target="_self">
#                  Board of Supervisors
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/County-Executive/News" linktype="3" target="_self">
#                  County Executive
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Parks/Experience/Events-Calendar" linktype="3" target="_self">
#                  Parks &amp; Recreation
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/News--Events/In-the-News" linktype="3" target="_self">
#                  In the News
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/News--Events/News">
#                  See All News
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li>
#               <a href="/EN/News--Events/Milwaukee-County-Free-Days" linktype="3" target="_self">
#                Milwaukee County Free Days
#               </a>
#               <ul>
#                <li>
#                 <a href="/EN/News--Events/Milwaukee-County-Free-Days" linktype="3" target="_self">
#                  Milwaukee Art Museum
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/News--Events/Milwaukee-County-Free-Days" linktype="3" target="_self">
#                  The Domes
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/News--Events/Milwaukee-County-Free-Days" linktype="3" target="_self">
#                  Milwaukee Public Museum
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/News--Events/Milwaukee-County-Free-Days" linktype="3" target="_self">
#                  Boerner Botanical Gardens
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/News--Events/Milwaukee-County-Free-Days" linktype="3" target="_self">
#                  Milwaukee County Zoo
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/News--Events/Milwaukee-County-Free-Days" linktype="3" target="_self">
#                  Charles Allis Art Museum
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/News--Events/Milwaukee-County-Free-Days" linktype="3" target="_self">
#                  Villa Terrace Decorative Arts Museum
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li>
#               <a href="/EN/Social-Media" linktype="3" target="_self">
#                Social Media
#               </a>
#               <ul>
#                <li>
#                 <a href="https://www.facebook.com/MilwaukeeCountyExecChrisAbele/" linktype="3" target="_blank">
#                  County Executive
#                 </a>
#                </li>
#                <li>
#                 <a href="https://www.facebook.com/MKECountyBoard/" linktype="3" target="_blank">
#                  Board of Supervisors
#                 </a>
#                </li>
#                <li>
#                 <a href="/EN/Social-Media" linktype="3" target="_self">
#                  View All Social Media
#                 </a>
#                </li>
#               </ul>
#              </li>
#             </ul>
#            </div>
#            <div blockinfo="Freeform New100 CenterZone TitanBlock" class="Freeform New100 CenterZone TitanBlock">
#             <h4>
#              <img alt="" src="/County-Files/County-of-Milwaukee/NewsEventsMegaMenu.jpg"/>
#             </h4>
#             <h4>
#              News &amp; Events
#             </h4>
#             <p>
#              Find information about things to do and happenings in Milwaukee County.
#             </p>
#             <p>
#             </p>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div id="WhiteLine">
#      </div>
#     </div>
#    </div>
#    <div id="MobileSearchBarWrapper">
#     <div class="siteBounds">
#      <!--BeginNoIndex-->
#      <div class="searchOuterWrapper">
#       <div class="searchInnerWrapper">
#        <input aria-label="Search by Keyword" autocomplete="off" id="mobileSearchBar_searchTerms" maxlength="200" name="mobileSearchBar_searchTerms" onkeypress="if(event.keyCode==13 || event.which==13) return false;" onkeyup="
#                 DefaultButton(event, document.getElementById('mobileSearchBar_searchGo'));
#
#                   NWS.SearchSegmentSupport.GetSuggestions(event, 39, 3, 2000, '/EN/Search', 'mobileSearchBar_', 5, true);
#                 " placeholder="Search Milwaukee County..." type="text" value=""/>
#        <input aria-label="Search" class="search" id="mobileSearchBar_searchGo" name="mobileSearchBar_searchGo" onclick="
#               SearchSubmit('/EN/Search', document.getElementById('mobileSearchBar_searchTerms'))
#             " type="button" value="Search"/>
#       </div>
#      </div>
#      <!--EndNoIndex-->
#     </div>
#    </div>
#    <div id="MenuOpacity">
#    </div>
#    <div id="featureWrapper">
#     <div id="featureText">
#      <div class="siteBounds">
# ...
#             <a href="/EN/Office-for-Persons-with-Disabilities" linktype="3" target="_self">
#              Office for Persons with Disabilities
#             </a>
#            </li>
#            <li>
#             <a href="/EN/mcjc" linktype="3" target="_self">
#              Milwaukee Community Justice Council
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li>
#           <a href="/EN/Residents/children--Families" linktype="3" target="_self">
#            Children &amp; Families
#           </a>
#           <ul>
#            <li>
#             <a href="/EN/Child-Support-Services" linktype="3" target="_self">
#              Child Support Services
#             </a>
#            </li>
#            <li>
#             <a href="/EN/County-Clerk/Marriage-License" linktype="3" target="_self">
#              Getting Married
#             </a>
#            </li>
#            <li>
#             <a href="/EN/dhhs/dyfs" linktype="3" target="_self">
#              Youth &amp; Family Services
#             </a>
#            </li>
#            <li>
#             <a href="/EN/Courts/Court-Divisions/Childrens-Court" linktype="3" target="_self">
#              Children's Court
#             </a>
#            </li>
#            <li>
#             <a href="/EN/Veterans-Services" linktype="3" target="_self">
#              Veterans' Services
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li>
#           <a href="/EN/residents/Health--Human-Services" linktype="3" target="_self">
#            Health &amp; Human Services
#           </a>
#           <ul>
#            <li>
#             <a href="/EN/DHHS/BHD" linktype="3" target="_self">
#              Behavioral Health Help
#             </a>
#            </li>
#            <li>
#             <a href="/EN/Department-on-Aging" linktype="3" target="_self">
#              Aging &amp; Older Adults
#             </a>
#            </li>
#            <li>
#             <a href="/EN/DHHS/dsd" linktype="3" target="_self">
#              Disability Services
#             </a>
#            </li>
#            <li>
#             <a href="/EN/dhhs/bhd" linktype="3" target="_self">
#              Comprehensive Community Services
#             </a>
#            </li>
#            <li>
#             <a href="/EN/dhhs/bhd" linktype="3" target="_self">
#              Crisis Clinics &amp; Centers
#             </a>
#            </li>
#            <li>
#             <a href="/EN/Office-for-Persons-with-Disabilities" linktype="3" target="_self">
#              Office for Persons with Disabilities
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li>
#           <a href="/EN/residents/Housing--Development" linktype="3" target="_self">
#            Housing &amp; Development
#           </a>
#           <ul>
#            <li>
#             <a href="/EN/DHHS/Housing#homeRepair" linktype="3" target="_self">
#              Home Repair
#             </a>
#            </li>
#            <li>
#             <a href="/EN/DHHS/Energy-Assistance" linktype="3" target="_self">
#              Energy Assistance
#             </a>
#            </li>
#            <li>
#             <a href="/EN/dhhs/housing/housing-first" linktype="3" target="_self">
#              Economic Support
#             </a>
#            </li>
#            <li>
#             <a href="/EN/administrative-services/land-information-office" linktype="3" target="_self">
#              Maps &amp; Data
#             </a>
#            </li>
#            <li>
#             <a href="/EN/Register-of-Deeds/Real-Estate-Record-Access" linktype="3" target="_self">
#              Real Estate Records
#             </a>
#            </li>
#            <li>
#             <a href="/EN/Administrative-Services/Economic-Development/Foreclosed-Properties" linktype="3" target="_self">
#              Foreclosed Properties for Sale
#             </a>
#            </li>
#            <li>
#             <a href="/EN/dhhs/housing" linktype="3" target="_self">
#              Housing Division
#             </a>
#            </li>
#           </ul>
#          </li>
#         </ul>
#        </div>
#        <div blockinfo="Freeform New100 CenterZone TitanBlock" class="Freeform New100 CenterZone TitanBlock">
#         <h4>
#          <img alt="" src="/County-Files/County-of-Milwaukee/ResidentMegaMenu.jpg"/>
#         </h4>
#         <h4>
#          Residents
#         </h4>
#         <p>
#          Milwaukee County is home to over 950,000 people living in one of 19 communities, which range in size from the City of Milwaukee, with 595,000 residents, to the Village of River Hills, with roughly 1,600 residents.
#         </p>
#        </div>
#       </div>
#       <div class="MobileMenuContainer" id="MobileMegaMenu4">
#        <div blockinfo="Freeform New100 CenterZone TitanBlock" class="Freeform New100 CenterZone TitanBlock">
#         <ul>
#          <li>
#           <a href="/EN/businesses/Doing-Business-with-the-County" linktype="3" target="_self">
#            Doing Business With the County
#           </a>
#           <ul>
#            <li>
#             <a href="/EN/Businesses/Doing-Business-with-the-County/First-Steps-in-Doing-Business-with-Milwaukee-County" linktype="3" target="_self">
#              First Steps in Doing Business With Milwaukee County
#             </a>
#            </li>
#            <li>
#             <a href="/EN/administrative-services/bids-and-rfps" linktype="3" target="_self">
#              Bids &amp; RFPs
#             </a>
#            </li>
#            <li>
#             <a href="/EN/administrative-services/community-business-development-partners/resources#ucp" linktype="3" target="_self">
#              Vendor Information
#             </a>
#            </li>
#            <li>
#             <a href="/EN/administrative-services/procurement#DocuSign" linktype="3" target="_self">
#              DocuSign Training
#             </a>
#            </li>
#            <li>
#             <a href="/En/administrative-services/land-information-office/gis-applications" linktype="3" target="_self">
#              Maps &amp; Apps
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li>
#           <a href="/EN/administrative-services/Community-Business-Development-Partners" linktype="3" target="_self">
#            Community Business Development Partners
#           </a>
#           <ul>
#            <li>
#             <a href="/EN/administrative-services/Community-Business-Development-Partners#certification" linktype="3" target="_self">
#              Certification Services
#             </a>
#            </li>
#            <li>
#             <a href="/EN/administrative-services/Community-Business-Development-Partners/resources#ucp" linktype="3" target="_self">
#              Certified Vendor List
#             </a>
#            </li>
#            <li>
#             <a href="https://mke.diversitycompliance.com/Default.asp" linktype="3" target="_blank">
#              B2GNow Access
#             </a>
#            </li>
#            <li>
#             <a href="/EN/administrative-services/Community-Business-Development-Partners#Revolving_Loan_Program" linktype="3" target="_self">
#              Revolving Loan Program
#             </a>
#            </li>
#            <li>
#             <a href="/EN/administrative-services/Community-Business-Development-Partners/Resources#goal_reports" linktype="3" target="_self">
#              DBE Goal Reports
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li>
#           <a href="/EN/Administrative-Services/Land-Information-Office" linktype="3" target="_self">
#            Land Information
#           </a>
#           <ul>
#            <li>
#             <a href="/EN/Administrative-Services/Land-Information-Office/GIS-Applications" linktype="3" target="_self">
#              GIS Applications
#             </a>
#            </li>
#            <li>
#             <a href="/EN/Administrative-Services/Land-Information-Office/GIS-Data-Downloads" linktype="3" target="_self">
#              GIS Data Downloads
#             </a>
#            </li>
#            <li>
#             <a href="/EN/Administrative-Services/Land-Information-Office/Maps" linktype="3" target="_self">
#              Maps
#             </a>
#            </li>
#            <li>
#             <a href="/EN/Administrative-Services/Land-Information-Office/Projects" linktype="3" target="_self">
#              Projects
#             </a>
#            </li>
#            <li>
#             <a href="/EN/Administrative-Services/Land-Information-Office/about-us/Land-Information-Council" linktype="3" target="_self">
#              Land Information Council
#             </a>
#            </li>
#            <li>
#             <a href="/EN/Administrative-Services/Land-Information-Office/About-Us" linktype="3" target="_self">
#              About
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li>
#           <a href="/EN/businesses/taxes--payments" linktype="3" target="_self">
#            Taxes &amp; Payments
#           </a>
#           <ul>
#            <li>
#             <a href="/EN/Treasurer/Delinquent-Property-Taxes" linktype="3" target="_self">
#              Pay Delinquent Property Taxes
#             </a>
#            </li>
#            <li>
#             <a href="/EN/Treasurer#unclaimed_funds" linktype="3" target="_self">
#              Unclaimed Funds
#             </a>
#            </li>
#            <li>
#             <a href="/EN/Treasurer#tax_credit" linktype="3" target="_self">
#              Tax Credits
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li>
#           <a href="/EN/administrative-services/Economic-Development" linktype="3" target="_self">
#            Economic Development
#           </a>
#           <ul>
#            <li>
#             <a href="/EN/administrative-services/Economic-Development#Projects" linktype="3" target="_self">
#              Projects
#             </a>
#            </li>
#            <li>
#             <a href="/EN/administrative-services/bids-and-RFPs" linktype="3" target="_self">
#              Bids &amp; RFPs
#             </a>
#            </li>
#            <li>
#             <a href="/EN/Administrative-Services/Economic-Development/Foreclosed-Properties" linktype="3" target="_self">
#              Real Estate
#             </a>
#            </li>
#            <li>
#             <a href="/EN/administrative-services/economic-development#contact_us" linktype="3" target="_self">
#              Contact
#             </a>
#            </li>
#           </ul>
#          </li>
#         </ul>
#        </div>
#        <div blockinfo="Freeform New100 CenterZone TitanBlock" class="Freeform New100 CenterZone TitanBlock">
#         <h4>
#          <img alt="" src="/County-Files/County-of-Milwaukee/BusinessMegaMenu.jpg"/>
#         </h4>
#         <h4>
#          Businesses
#         </h4>
#         <p>
#          Still a manufacturing stronghold, the region features 16 Fortune 1000 companies and thousands of others in the financial services, medical device, hospitality and retailing industries.
#         </p>
#        </div>
#       </div>
#       <div class="MobileMenuContainer" id="MobileMegaMenu5">
#        <div blockinfo="Freeform New100 CenterZone TitanBlock" class="Freeform New100 CenterZone TitanBlock">
#         <ul>
#          <li>
#           <a href="/EN/News--Events/Events" linktype="3" target="_self">
#            Events
#           </a>
#           <ul>
#            <li>
#             <a href="/EN/Parks/Experience/Events-Calendar" linktype="3" target="_self">
#              Events at the Parks
#             </a>
#            </li>
#            <li>
#             <a href="https://milwaukeecounty.legistar.com/Calendar.aspx" linktype="3" target="_blank">
#              Board Meetings
#             </a>
#            </li>
#            <li>
#             <a href="https://milwaukeecounty.legistar.com/Calendar.aspx" linktype="3" target="_blank">
#              Committee Meetings
#             </a>
#            </li>
#            <li>
#             <a href="https://milwaukeecounty.legistar.com/Calendar.aspx" linktype="3" target="_blank">
#              Subcommittee Meetings
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li>
#           <a href="/EN/News--Events/News" linktype="3" target="_self">
#            News
#           </a>
#           <ul>
#            <li>
#             <a href="/EN/Board-of-Supervisors/News" linktype="3" target="_self">
#              Board of Supervisors
#             </a>
#            </li>
#            <li>
#             <a href="/EN/County-Executive/News" linktype="3" target="_self">
#              County Executive
#             </a>
#            </li>
#            <li>
#             <a href="/EN/Parks/Experience/Events-Calendar" linktype="3" target="_self">
#              Parks &amp; Recreation
#             </a>
#            </li>
#            <li>
#             <a href="/EN/News--Events/In-the-News" linktype="3" target="_self">
#              In the News
#             </a>
#            </li>
#            <li>
#             <a href="/EN/News--Events/News">
#              See All News
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li>
#           <a href="/EN/News--Events/Milwaukee-County-Free-Days" linktype="3" target="_self">
#            Milwaukee County Free Days
#           </a>
#           <ul>
#            <li>
#             <a href="/EN/News--Events/Milwaukee-County-Free-Days" linktype="3" target="_self">
#              Milwaukee Art Museum
#             </a>
#            </li>
#            <li>
#             <a href="/EN/News--Events/Milwaukee-County-Free-Days" linktype="3" target="_self">
#              The Domes
#             </a>
#            </li>
#            <li>
#             <a href="/EN/News--Events/Milwaukee-County-Free-Days" linktype="3" target="_self">
#              Milwaukee Public Museum
#             </a>
#            </li>
#            <li>
#             <a href="/EN/News--Events/Milwaukee-County-Free-Days" linktype="3" target="_self">
#              Boerner Botanical Gardens
#             </a>
#            </li>
#            <li>
#             <a href="/EN/News--Events/Milwaukee-County-Free-Days" linktype="3" target="_self">
#              Milwaukee County Zoo
#             </a>
#            </li>
#            <li>
#             <a href="/EN/News--Events/Milwaukee-County-Free-Days" linktype="3" target="_self">
#              Charles Allis Art Museum
#             </a>
#            </li>
#            <li>
#             <a href="/EN/News--Events/Milwaukee-County-Free-Days" linktype="3" target="_self">
#              Villa Terrace Decorative Arts Museum
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li>
#           <a href="/EN/Social-Media" linktype="3" target="_self">
#            Social Media
#           </a>
#           <ul>
#            <li>
#             <a href="https://www.facebook.com/MilwaukeeCountyExecChrisAbele/" linktype="3" target="_blank">
#              County Executive
#             </a>
#            </li>
#            <li>
#             <a href="https://www.facebook.com/MKECountyBoard/" linktype="3" target="_blank">
#              Board of Supervisors
#             </a>
#            </li>
#            <li>
#             <a href="/EN/Social-Media" linktype="3" target="_self">
#              View All Social Media
#             </a>
#            </li>
#           </ul>
#          </li>
#         </ul>
#        </div>
#        <div blockinfo="Freeform New100 CenterZone TitanBlock" class="Freeform New100 CenterZone TitanBlock">
#         <h4>
#          <img alt="" src="/County-Files/County-of-Milwaukee/NewsEventsMegaMenu.jpg"/>
#         </h4>
#         <h4>
#          News &amp; Events
#         </h4>
#         <p>
#          Find information about things to do and happenings in Milwaukee County.
#         </p>
#         <p>
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div id="MobileMenuOpacity">
#    </div>
#    <div id="MobileSearchOpacity">
#    </div>
#    <div id="printFooter">
#     <div class="siteBounds">
#     </div>
#    </div>
#    <input air="flowplayer.controls-air-3.2.12.swf" basedir="/display/components/Blocks/Freeform_CK/ckeditor/plugins/titanflowplayer/" id="flowPlayerSettings" js="flowplayer-3.2.11.min.js" modern="flowplayer.controls-3.2.12.swf" pseudo="flowplayer.pseudostreaming-3.2.9.swf" swf="flowplayer-3.2.12.swf" tube="flowplayer.controls-tube-3.2.12.swf" type="hidden"/>
#   </form>
#  </body>
# </html>
