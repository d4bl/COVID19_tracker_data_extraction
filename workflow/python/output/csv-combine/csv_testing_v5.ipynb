# %% [markdown]
# # Daily CSV Combination & Standardization
# *Jamie Prezioso, September 19, 2020*
#
# This notebook is testing how to standardize daily CSV files from the COVID-19 dataset for D4BL.
#
# **Completed** - *Goal of version 2 - Earlier runs didn’t include the run date, so that column will always be missing for those tables. You could extract the run date from the file name and insert it into the empty record. Accomplished in _v2*
#
# **Completed** - *Goal of version 3 - Is there a way to concatenate the dataframes without including the row numbers (indices)? My preference is to have the index of the final table as the set of consecutive integers 1-n or 0-(n-1), without duplicate indices.*
# Including the `index=True` argument fixes this:  `dfCombined.to_csv("combinedData{}.csv".format(date_object), index=True)`
#
# **Completed** *Could you also sort the final table by run date and by location?* Sorted by date and location (alphabetically), and checked for duplicate locations.  *Note, when checking for duplicate locations, this prints a warning and exits the loop, the CSV merging does not complete.*

# %%
import os
import glob
import pandas as pd
import shutil
import numpy as np

# %% [markdown]
# ## Test with a few CSV files

# %% [markdown]
# ### Grab three different CSVs

# %%
# Test files 
f1 = '../csv/covid_disparities_output_2020-08-01.csv'
f2 = '../csv/covid_disparities_output_2020-08-19.csv' # Most recent
f3 = '../csv/covid_disparities_output_2020-07-01.csv'

# %%
df1 = pd.read_csv(f1)
c1 = list(df1.columns)
print('Filename: ' + f1)
df1.head()
# Out:
# Filename: ../csv/covid_disparities_output_2020-08-01.csv
#          Location Date Published  Total Cases  Total Deaths  \
# 0        Illinois     2020-08-01     180476.0        7503.0
# 1       Louisiana     2020-07-29     116280.0        3835.0
# 2      Washington     2020-08-01      57541.0        1592.0
# 3  North Carolina     2020-08-01     123878.0        1964.0
# 4         Wyoming     2020-08-01       2769.0          26.0
#
#    Count Cases Black/AA  Count Deaths Black/AA  Pct Cases Black/AA  \
# 0               29784.0                 2059.0               16.50
# 1               41962.0                 1884.0               44.38
# 2                2134.0                   51.0                5.49
# 3               21584.0                  591.0               24.06
# 4                  27.0                    0.0                1.01
#
#    Pct Deaths Black/AA  Pct Includes Unknown Race  \
# 0                27.44                       True
# 1                50.36                      False
# 2                 3.29                      False
# 3                31.30                      False
# 4                 0.00                      False
#
#    Pct Includes Hispanic Black  Count Cases Known Race  \
# 0                        False                     NaN
# 1                         True                 94556.0
# 2                        False                 38840.0
# 3                         True                 89713.0
# 4                        False                  2669.0
#
#    Count Deaths Known Race  Black/AA Population  Pct Black/AA Population  \
# 0                      NaN            1824125.0                    14.23
# 1                   3741.0            1502916.0                    32.23
# 2                   1551.0             269854.0                     3.70
# 3                   1888.0            2179622.0                    21.46
# 4                     25.0               5540.0                     0.95
#
#   Status code
# 0    Success!
# 1    Success!
# 2    Success!
# 3    Success!
# 4    Success!

# %%
print('Filename: ' + f2)
df2 = pd.read_csv(f2)
c2 = list(df2.columns)
df2.head()
# Out:
# Filename: ../csv/covid_disparities_output_2020-08-19.csv
#      Date Run                              Date/Time Run    Location  \
# 0  2020-08-19  2020/08/19 19:34:57America/Los Angeles TZ     Alabama
# 1  2020-08-19  2020/08/19 19:34:57America/Los Angeles TZ      Alaska
# 2  2020-08-19  2020/08/19 19:34:57America/Los Angeles TZ     Arizona
# 3  2020-08-19  2020/08/19 19:34:57America/Los Angeles TZ    Arkansas
# 4  2020-08-19  2020/08/19 19:34:57America/Los Angeles TZ  California
#
#         Date Published  Total Cases  Total Deaths  Count Cases Black/AA  \
# 0           2020-08-19     106784.0        1876.0               28664.0
# 1           2020-08-19       2731.0          28.0                 154.0
# 2           2020-08-19     195557.0        4634.0                4918.0
# 3           2020-08-19      54216.0         631.0               11909.0
# 4  2020-08-17 00:00:00     632667.0       11342.0               17615.0
#
#    Count Deaths Black/AA  Pct Cases Black/AA  Pct Deaths Black/AA  \
# 0                  769.0               41.92                42.51
# 1                    0.0                6.31                 0.00
# 2                  142.0                4.50                 3.55
# 3                  163.0               24.59                25.83
# 4                  876.0                4.28                 8.03
#
#    Pct Includes Unknown Race  Pct Includes Hispanic Black  \
# 0                      False                        False
# 1                      False                         True
# 2                      False                        False
# 3                      False                         True
# 4                      False                        False
#
#    Count Cases Known Race  Count Deaths Known Race  Black/AA Population  \
# 0                 68376.0                   1809.0            1293186.0
# 1                  2441.0                     28.0              24129.0
# 2                109208.0                   3997.0             305259.0
# 3                 48431.0                    631.0             460970.0
# 4                411365.0                  10910.0            2267875.0
#
#    Pct Black/AA Population Status code
# 0                    26.58    Success!
# 1                     3.27    Success!
# 2                     4.39    Success!
# 3                    15.41    Success!
# 4                     5.79    Success!

# %%
df3 = pd.read_csv(f3)
print('Filename: ' + f3)
c3 = list(df3.columns)
df3.head()
# Out:
# Filename: ../csv/covid_disparities_output_2020-07-01.csv
#                  Location Date Published  Total Cases  Total Deaths  \
# 0              Washington     2020-07-01      33435.0        1339.0
# 1          North Carolina     2020-07-01      66513.0        1373.0
# 2             NewYorkCity     2020-07-01     212412.0       18497.0
# 3               Wisconsin     2020-07-01      29199.0         786.0
# 4  Wisconsin -- Milwaukee     2020-07-01      11553.0         355.0
#
#    Count Cases Black/AA Count Deaths Black/AA  Pct Cases Black/AA  \
# 0                1366.0                  43.0                6.00
# 1               10818.0                 436.0               16.26
# 2               33061.0                5166.0               30.16
# 3                5085.0                 185.0               19.43
# 4                3289.0                 143.0               30.77
#
#    Pct Deaths Black/AA  Pct Includes Unknown Race  \
# 0                 3.00                      False
# 1                31.76                      False
# 2                30.48                      False
# 3                23.87                      False
# 4                40.28                      False
#
#    Pct Includes Hispanic Black Status code
# 0                        False    Success!
# 1                         True    Success!
# 2                         True    Success!
# 3                         True    Success!
# 4                        False    Success!

# %%
# Do any of the 3 data sets have the same col. headers?
print(set(c1) == set(c2))
print(set(c2) == set(c3))
print(set(c1) == set(c3))
# Out:
# False
# False
# False

# %%
print(len(c1))
print(len(c2))
print(len(c3))
# Out:
# 15
# 17
# 11

# %%
c1
# Out:
# ['Location',
#  'Date Published',
#  'Total Cases',
#  'Total Deaths',
#  'Count Cases Black/AA',
#  'Count Deaths Black/AA',
#  'Pct Cases Black/AA',
#  'Pct Deaths Black/AA',
#  'Pct Includes Unknown Race',
#  'Pct Includes Hispanic Black',
#  'Count Cases Known Race',
#  'Count Deaths Known Race',
#  'Black/AA Population',
#  'Pct Black/AA Population',
#  'Status code']

# %%
c2
# Out:
# ['Date Run',
#  'Date/Time Run',
#  'Location',
#  'Date Published',
#  'Total Cases',
#  'Total Deaths',
#  'Count Cases Black/AA',
#  'Count Deaths Black/AA',
#  'Pct Cases Black/AA',
#  'Pct Deaths Black/AA',
#  'Pct Includes Unknown Race',
#  'Pct Includes Hispanic Black',
#  'Count Cases Known Race',
#  'Count Deaths Known Race',
#  'Black/AA Population',
#  'Pct Black/AA Population',
#  'Status code']

# %%
c3
# Out:
# ['Location',
#  'Date Published',
#  'Total Cases',
#  'Total Deaths',
#  'Count Cases Black/AA',
#  'Count Deaths Black/AA',
#  'Pct Cases Black/AA',
#  'Pct Deaths Black/AA',
#  'Pct Includes Unknown Race',
#  'Pct Includes Hispanic Black',
#  'Status code']

# %% [markdown]
# ### Combine those three CSVs

# %% [markdown]
# Using `pandas.DataFrame.merge` essentially takes the union of the column headers.  If a dataset does not have a column, but the set it is being merged with does, those column entries are set to NaN.  Alternatively, we could use `pandas.concat`.  Let's try both...
#
# I think `pandas.concat` is the way to go for this since we're merging multiple dataframes into one dataframe (and then exporting as a CSV).  The merging option is a method of an individual data frame so this seems a bit clunky to do for multiple at once, however, once we have the full, up-to-date time series CSV, then we could use `merge` to perform a daily update.

# %%
# Downselect for easy inspection:
df1sm = df1[0:3]
df2sm = df2[0:4]
df3sm = df3[0:2]

# %%
outer_merged = df1sm.merge(df2sm, how="outer")
outer_merged.head()
print(outer_merged.shape)
outer_merged
# Out:
# (7, 17)
#      Location Date Published  Total Cases  Total Deaths  Count Cases Black/AA  \
# 0    Illinois     2020-08-01     180476.0        7503.0               29784.0
# 1   Louisiana     2020-07-29     116280.0        3835.0               41962.0
# 2  Washington     2020-08-01      57541.0        1592.0                2134.0
# 3     Alabama     2020-08-19     106784.0        1876.0               28664.0
# 4      Alaska     2020-08-19       2731.0          28.0                 154.0
# 5     Arizona     2020-08-19     195557.0        4634.0                4918.0
# 6    Arkansas     2020-08-19      54216.0         631.0               11909.0
#
#    Count Deaths Black/AA  Pct Cases Black/AA  Pct Deaths Black/AA  \
# 0                 2059.0               16.50                27.44
# 1                 1884.0               44.38                50.36
# 2                   51.0                5.49                 3.29
# 3                  769.0               41.92                42.51
# 4                    0.0                6.31                 0.00
# 5                  142.0                4.50                 3.55
# 6                  163.0               24.59                25.83
#
#   Pct Includes Unknown Race Pct Includes Hispanic Black  \
# 0                      True                       False
# 1                     False                        True
# 2                     False                       False
# 3                     False                       False
# 4                     False                        True
# 5                     False                       False
# 6                     False                        True
#
#    Count Cases Known Race  Count Deaths Known Race  Black/AA Population  \
# 0                     NaN                      NaN            1824125.0
# 1                 94556.0                   3741.0            1502916.0
# 2                 38840.0                   1551.0             269854.0
# 3                 68376.0                   1809.0            1293186.0
# 4                  2441.0                     28.0              24129.0
# 5                109208.0                   3997.0             305259.0
# 6                 48431.0                    631.0             460970.0
#
#    Pct Black/AA Population Status code    Date Run  \
# 0                    14.23    Success!         NaN
# 1                    32.23    Success!         NaN
# 2                     3.70    Success!         NaN
# 3                    26.58    Success!  2020-08-19
# 4                     3.27    Success!  2020-08-19
# 5                     4.39    Success!  2020-08-19
# 6                    15.41    Success!  2020-08-19
#
#                                Date/Time Run
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3  2020/08/19 19:34:57America/Los Angeles TZ
# 4  2020/08/19 19:34:57America/Los Angeles TZ
# 5  2020/08/19 19:34:57America/Los Angeles TZ
# 6  2020/08/19 19:34:57America/Los Angeles TZ

# %%
print(type(outer_merged))
print(type(df3sm))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
#outer_merged2 = outer_merged.merge(df3sm, how="outer")
#outer_merged2.head()
#print(outer_merged2.shape)
#outer_merged2

# %%
pd.concat([df1sm,df2sm,df3sm],ignore_index=True)
# Out:
#          Location Date Published  Total Cases  Total Deaths  \
# 0        Illinois     2020-08-01     180476.0        7503.0
# 1       Louisiana     2020-07-29     116280.0        3835.0
# 2      Washington     2020-08-01      57541.0        1592.0
# 3         Alabama     2020-08-19     106784.0        1876.0
# 4          Alaska     2020-08-19       2731.0          28.0
# 5         Arizona     2020-08-19     195557.0        4634.0
# 6        Arkansas     2020-08-19      54216.0         631.0
# 7      Washington     2020-07-01      33435.0        1339.0
# 8  North Carolina     2020-07-01      66513.0        1373.0
#
#    Count Cases Black/AA Count Deaths Black/AA  Pct Cases Black/AA  \
# 0               29784.0                  2059               16.50
# 1               41962.0                  1884               44.38
# 2                2134.0                    51                5.49
# 3               28664.0                   769               41.92
# 4                 154.0                     0                6.31
# 5                4918.0                   142                4.50
# 6               11909.0                   163               24.59
# 7                1366.0                  43.0                6.00
# 8               10818.0                 436.0               16.26
#
#    Pct Deaths Black/AA  Pct Includes Unknown Race  \
# 0                27.44                       True
# 1                50.36                      False
# 2                 3.29                      False
# 3                42.51                      False
# 4                 0.00                      False
# 5                 3.55                      False
# 6                25.83                      False
# 7                 3.00                      False
# 8                31.76                      False
#
#    Pct Includes Hispanic Black  Count Cases Known Race  \
# 0                        False                     NaN
# 1                         True                 94556.0
# 2                        False                 38840.0
# 3                        False                 68376.0
# 4                         True                  2441.0
# 5                        False                109208.0
# 6                         True                 48431.0
# 7                        False                     NaN
# 8                         True                     NaN
#
#    Count Deaths Known Race  Black/AA Population  Pct Black/AA Population  \
# 0                      NaN            1824125.0                    14.23
# 1                   3741.0            1502916.0                    32.23
# 2                   1551.0             269854.0                     3.70
# 3                   1809.0            1293186.0                    26.58
# 4                     28.0              24129.0                     3.27
# 5                   3997.0             305259.0                     4.39
# 6                    631.0             460970.0                    15.41
# 7                      NaN                  NaN                      NaN
# 8                      NaN                  NaN                      NaN
#
#   Status code    Date Run                              Date/Time Run
# 0    Success!         NaN                                        NaN
# 1    Success!         NaN                                        NaN
# 2    Success!         NaN                                        NaN
# 3    Success!  2020-08-19  2020/08/19 19:34:57America/Los Angeles TZ
# 4    Success!  2020-08-19  2020/08/19 19:34:57America/Los Angeles TZ
# 5    Success!  2020-08-19  2020/08/19 19:34:57America/Los Angeles TZ
# 6    Success!  2020-08-19  2020/08/19 19:34:57America/Los Angeles TZ
# 7    Success!         NaN                                        NaN
# 8    Success!         NaN                                        NaN

# %% [markdown]
# The above concatenated dataframe is as expected so lets try it for all of the CSVs located in a folder...

# %% [markdown]
# ## Create an initial CSV of all currently available data

# %% [markdown]
# ## Create a method which will update the latest CSV

# %%
# %pwd
# %ls
# Out:
# combinecsv.py
# combinedData.csv
# combinedData2020-08-30 21:21:47.350984.csv
# combinedData2020-08-31 09:37:58.178116.csv
# csv_testing_v1.ipynb
# csv_testing_v2.ipynb
# csv_testing_v5.ipynb
# someoutputfile.csv

# %%
# Where's the folder of *exclusively* CSVs of interest
csvPath = '../csv-short'

#import csv files from folder
path = csvPath

allFiles = glob.glob(path + "/*.csv")
# Need to sort these
allFiles.sort()

# %%
allFiles
# Out:
# ['../csv-short/covid_disparities_output_2020-05-08.csv',
#  '../csv-short/covid_disparities_output_2020-05-09.csv',
#  '../csv-short/covid_disparities_output_2020-05-10.csv',
#  '../csv-short/covid_disparities_output_2020-05-11.csv',
#  '../csv-short/covid_disparities_output_2020-05-12.csv',
#  '../csv-short/covid_disparities_output_2020-05-13.csv',
#  '../csv-short/covid_disparities_output_2020-05-22.csv',
#  '../csv-short/covid_disparities_output_2020-06-07.csv',
#  '../csv-short/covid_disparities_output_2020-06-08.csv',
#  '../csv-short/covid_disparities_output_2020-06-09.csv',
#  '../csv-short/covid_disparities_output_2020-06-10.csv',
#  '../csv-short/covid_disparities_output_2020-06-16.csv',
#  '../csv-short/covid_disparities_output_2020-06-25.csv',
#  '../csv-short/covid_disparities_output_2020-06-27.csv',
#  '../csv-short/covid_disparities_output_2020-06-28.csv',
#  '../csv-short/covid_disparities_output_2020-06-29.csv',
#  '../csv-short/covid_disparities_output_2020-06-30.csv',
#  '../csv-short/covid_disparities_output_2020-07-01.csv',
#  '../csv-short/covid_disparities_output_2020-07-02.csv',
#  '../csv-short/covid_disparities_output_2020-07-03.csv',
#  '../csv-short/covid_disparities_output_2020-07-04.csv',
#  '../csv-short/covid_disparities_output_2020-07-05.csv',
#  '../csv-short/covid_disparities_output_2020-07-06.csv',
#  '../csv-short/covid_disparities_output_2020-07-07.csv',
#  '../csv-short/covid_disparities_output_2020-07-08.csv',
#  '../csv-short/covid_disparities_output_2020-07-09.csv',
#  '../csv-short/covid_disparities_output_2020-07-10.csv',
#  '../csv-short/covid_disparities_output_2020-07-11.csv',
#  '../csv-short/covid_disparities_output_2020-07-12.csv',
#  '../csv-short/covid_disparities_output_2020-07-13.csv',
#  '../csv-short/covid_disparities_output_2020-07-14.csv',
#  '../csv-short/covid_disparities_output_2020-07-15.csv',
#  '../csv-short/covid_disparities_output_2020-07-16.csv',
#  '../csv-short/covid_disparities_output_2020-07-17.csv',
#  '../csv-short/covid_disparities_output_2020-07-18.csv',
#  '../csv-short/covid_disparities_output_2020-07-19.csv',
#  '../csv-short/covid_disparities_output_2020-07-20.csv',
#  '../csv-short/covid_disparities_output_2020-07-21.csv',
#  '../csv-short/covid_disparities_output_2020-07-22.csv',
#  '../csv-short/covid_disparities_output_2020-07-23.csv',
#  '../csv-short/covid_disparities_output_2020-07-24.csv',
#  '../csv-short/covid_disparities_output_2020-07-25.csv',
#  '../csv-short/covid_disparities_output_2020-07-26.csv',
#  '../csv-short/covid_disparities_output_2020-07-27.csv',
#  '../csv-short/covid_disparities_output_2020-07-28.csv',
#  '../csv-short/covid_disparities_output_2020-07-29.csv',
#  '../csv-short/covid_disparities_output_2020-07-30.csv',
#  '../csv-short/covid_disparities_output_2020-07-31.csv',
#  '../csv-short/covid_disparities_output_2020-08-01.csv',
#  '../csv-short/covid_disparities_output_2020-08-02.csv',
#  '../csv-short/covid_disparities_output_2020-08-03.csv',
#  '../csv-short/covid_disparities_output_2020-08-04.csv',
#  '../csv-short/covid_disparities_output_2020-08-05.csv',
#  '../csv-short/covid_disparities_output_2020-08-06.csv',
#  '../csv-short/covid_disparities_output_2020-08-07.csv',
#  '../csv-short/covid_disparities_output_2020-08-08.csv',
#  '../csv-short/covid_disparities_output_2020-08-09.csv',
#  '../csv-short/covid_disparities_output_2020-08-10.csv',
#  '../csv-short/covid_disparities_output_2020-08-11.csv',
#  '../csv-short/covid_disparities_output_2020-08-12.csv',
#  '../csv-short/covid_disparities_output_2020-08-13.csv',
#  '../csv-short/covid_disparities_output_2020-08-14.csv',
#  '../csv-short/covid_disparities_output_2020-08-15.csv',
#  '../csv-short/covid_disparities_output_2020-08-16.csv',
#  '../csv-short/covid_disparities_output_2020-08-17.csv',
#  '../csv-short/covid_disparities_output_2020-08-18.csv',
#  '../csv-short/covid_disparities_output_2020-08-19.csv',
#  '../csv-short/covid_disparities_output_2020-08-20.csv',
#  '../csv-short/covid_disparities_output_2020-08-21.csv']

# %%
#combine all files in the list
#dfCombined = pd.concat([pd.read_csv(f) for f in allFiles], ignore_index=True)

# %%
f = allFiles[0]
print(len(f))
f[-14:-4:]
# Out:
# 52
# '2020-05-08'

# %%
print(any(df['Student'].duplicated()))

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
csvList = []
for f in allFiles:
    # Get dataframe of current file
    dfCurr = pd.read_csv(f)
    
    # Set Date Run, if not already set, from file name
    if not 'Date Run' in dfCurr.keys():
        dateCurr = f[-14:-4:]
        dfCurr['Date Run'] = dateCurr
        print('Adding Date run on ', dateCurr)
    
    # Sort current df by location
    #sort dataframe
    dfCurrSorted = dfCurr.sort_values(by='Location', ascending=True)
    
    # Drop the index
    # dfCurr.reset_index(drop=True, inplace=True)
    
    # Check for duplicate records: A location should only 
    # appear once in any given dfCurr
    if any(dfCurrSorted.duplicated(subset=['Location'])):
        print('Duplicate entry in {}'.format(f))
        print('EXITING LOOP - TODO, delete row')
        break
    
    csvList.append(dfCurrSorted)
# Out:
# Adding Date run on  2020-05-08
# Adding Date run on  2020-05-09
# Adding Date run on  2020-05-10
# Adding Date run on  2020-05-11
# Adding Date run on  2020-05-12
# Adding Date run on  2020-05-13
# Adding Date run on  2020-05-22
# Adding Date run on  2020-06-07
# Adding Date run on  2020-06-08
# Adding Date run on  2020-06-09
# Adding Date run on  2020-06-10
# Adding Date run on  2020-06-16
# Adding Date run on  2020-06-25
# Adding Date run on  2020-06-27
# Adding Date run on  2020-06-28
# Adding Date run on  2020-06-29
# Adding Date run on  2020-06-30
# Adding Date run on  2020-07-01
# Adding Date run on  2020-07-02
# Adding Date run on  2020-07-03
# Adding Date run on  2020-07-04
# Adding Date run on  2020-07-05
# Adding Date run on  2020-07-06
# Adding Date run on  2020-07-07
# Adding Date run on  2020-07-08
# Adding Date run on  2020-07-09
# Adding Date run on  2020-07-10
# Adding Date run on  2020-07-11
# Adding Date run on  2020-07-12
# Adding Date run on  2020-07-13
# Adding Date run on  2020-07-14
# Adding Date run on  2020-07-15
# Adding Date run on  2020-07-16
# Adding Date run on  2020-07-17
# Adding Date run on  2020-07-18
# Adding Date run on  2020-07-19
# Adding Date run on  2020-07-20
# Adding Date run on  2020-07-21
# Adding Date run on  2020-07-22
# Adding Date run on  2020-07-23
# Adding Date run on  2020-07-24
# Adding Date run on  2020-07-25
# Adding Date run on  2020-07-26
# Adding Date run on  2020-07-29
# Adding Date run on  2020-07-30
# Adding Date run on  2020-07-31
# Adding Date run on  2020-08-01
# Adding Date run on  2020-08-02
# Adding Date run on  2020-08-03
# Adding Date run on  2020-08-04
# Adding Date run on  2020-08-05
# Adding Date run on  2020-08-06
# Adding Date run on  2020-08-07
# Adding Date run on  2020-08-08

# %%
dfCombined = pd.concat(csvList, ignore_index=True)

# %%
#dfCombined.columns

# %%
dfCombined
# Out:
#          Unnamed: 0                Location Date Published  Total Cases  \
# 0           Georgia                 Georgia       5/8/2020      32177.0
# 1     Massachusetts           Massachusetts       5/8/2020      75333.0
# 2          Virginia                Virginia       5/8/2020      22342.0
# 3     Washington DC          Washington, DC       5/8/2020       5899.0
# 4           Georgia                 Georgia       5/9/2020      32504.0
# ...             ...                     ...            ...          ...
# 2779            NaN          Washington, DC     2020-08-21      13469.0
# 2780            NaN            WestVirginia            NaN          NaN
# 2781            NaN               Wisconsin     2020-08-21      69059.0
# 2782            NaN  Wisconsin -- Milwaukee     2020-08-21      23032.0
# 2783            NaN                 Wyoming            NaN          NaN
#
#       Total Deaths  Pct Cases Black/AA  Pct Deaths Black/AA    Date Run  \
# 0           1400.0               36.00                49.57  2020-05-08
# 1           4702.0                8.18                 5.25  2020-05-08
# 2            812.0               17.15                22.41  2020-05-08
# 3            304.0               47.35                79.28  2020-05-08
# 4           1400.0               35.76                49.57  2020-05-09
# ...            ...                 ...                  ...         ...
# 2779         602.0               50.03                74.42  2020-08-21
# 2780           NaN                 NaN                  NaN  2020-08-21
# 2781        1068.0               14.84                20.65  2020-08-21
# 2782         397.0               29.03                37.53  2020-08-21
# 2783           NaN                 NaN                  NaN  2020-08-21
#
#                                             Status code  Count Cases Black/AA  \
# 0                                                   NaN                   NaN
# 1                                                   NaN                   NaN
# 2                                                   NaN                   NaN
# 3                                                   NaN                   NaN
# 4                                              Success!                   NaN
# ...                                                 ...                   ...
# 2779                                           Success!                6738.0
# 2780  An error occurred. ... TimeoutException('', No...                   NaN
# 2781                                           Success!                9274.0
# 2782                                           Success!                6257.0
# 2783  An error occurred. ... JSONDecodeError('Expect...                   NaN
#
#      Count Deaths Black/AA Pct Includes Unknown Race  \
# 0                      NaN                       NaN
# 1                      NaN                       NaN
# 2                      NaN                       NaN
# 3                      NaN                       NaN
# 4                      NaN                       NaN
# ...                    ...                       ...
# 2779                   448                      True
# 2780                   NaN                     False
# 2781                   217                     False
# 2782                   149                     False
# 2783                   NaN                     False
#
#      Pct Includes Hispanic Black  Count Cases Known Race  \
# 0                            NaN                     NaN
# 1                            NaN                     NaN
# 2                            NaN                     NaN
# 3                            NaN                     NaN
# 4                            NaN                     NaN
# ...                          ...                     ...
# 2779                        True                     NaN
# 2780                       False                     NaN
# 2781                        True                 62497.0
# 2782                       False                 21550.0
# 2783                       False                     NaN
#
#       Count Deaths Known Race  Black/AA Population  Pct Black/AA Population  \
# 0                         NaN                  NaN                      NaN
# 1                         NaN                  NaN                      NaN
# 2                         NaN                  NaN                      NaN
# 3                         NaN                  NaN                      NaN
# 4                         NaN                  NaN                      NaN
# ...                       ...                  ...                      ...
# 2779                      NaN             321317.0                    46.94
# 2780                      NaN                  NaN                      NaN
# 2781                   1051.0             368744.0                     6.38
# 2782                    397.0             252321.0                    26.44
# 2783                      NaN               5540.0                     0.95
#
#                                   Date/Time Run Date Run.1 Date/Time Run.1
# 0                                           NaN        NaN             NaN
# 1                                           NaN        NaN             NaN
# 2                                           NaN        NaN             NaN
# 3                                           NaN        NaN             NaN
# 4                                           NaN        NaN             NaN
# ...                                         ...        ...             ...
# 2779  2020/08/21 21:57:22America/Los Angeles TZ        NaN             NaN
# 2780  2020/08/21 21:57:22America/Los Angeles TZ        NaN             NaN
# 2781  2020/08/21 21:57:22America/Los Angeles TZ        NaN             NaN
# 2782  2020/08/21 21:57:22America/Los Angeles TZ        NaN             NaN
# 2783  2020/08/21 21:57:22America/Los Angeles TZ        NaN             NaN
#
# [2784 rows x 20 columns]

# %%
import datetime
date_object = datetime.datetime.now()
print(date_object)
# Out:
# 2020-08-31 09:37:58.178116

# %%
#export to csv
dfCombined.to_csv("combinedData{}.csv".format(date_object), index=True)#, encoding='utf-8-sig')

# %% [markdown]
# Attempting to extract CSVs from a folder which doesn't exclusively contain *only* the CSVs we want to merge... For some reason I need to pass through the data twice to eliminate everything... ?

# %%
csvPath = '../csv/'

# Get all files in csv dir
allFiles = os.listdir('../csv')
#print(allFiles)

for f in allFiles:
    #print(f)
    if not ('covid_disparities_output_2020-' in f):
        allFiles.remove(f)
        #print('removed ', f)

for f in allFiles:
    #print(f)
    if not ('covid_disparities_output_2020-' in f):
        allFiles.remove(f)
        #print('removed ', f)
